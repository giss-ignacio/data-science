# %%
# SF Crimes - ggplot2 - 02.ipynb
# Stacked Bar
# R code
# Ignacio Giss
#

library(ggplot2)
library(RColorBrewer)
# df5 is a sample with the most common crimes in SF by PdDistrict.

ggplot(df3, aes(x = PdDistrict, y = Crimes,fill=Category)) +
    geom_bar(stat='identity') +
    # colours palette
    scale_fill_brewer(palette="Spectral")
